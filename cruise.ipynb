# %% [markdown]
# # Cruise data
#
# Everything is better explained in takeoff.ipynb

# %%
import iocommon
import logging
import matplotlib.pyplot as plt
import pandas as pd
import cruise

# %matplotlib inline
plt.rcParams['figure.figsize'] = [18, 12]

data = cruise.find_cruise_data(pd.read_feather('/Users/mfdutra/Documents/flights.feather'))

# %% [markdown]
# # CHT

# %%
cruise.analyze(data[['E1 CHT1', 'E1 CHT2', 'E1 CHT3', 'E1 CHT4']])
# Out:
#              E1 CHT1        E1 CHT2        E1 CHT3        E1 CHT4
# count  695236.000000  695236.000000  695236.000000  695236.000000
# mean      352.896701     344.301549     370.664639     360.242723
# std        21.781879      19.532843      22.341476      20.448574
# min       201.320000     177.210000     199.190000     199.670000
# 25%       342.400000     334.690000     360.170000     350.950000
# 50%       356.570000     347.770000     374.330000     362.820000
# 75%       368.010000     357.850000     385.530000     374.350000
# max       425.660000     411.870000     436.980000     430.160000

# %% [markdown]
# # EGT

# %%
cruise.analyze(data[['E1 EGT1', 'E1 EGT2', 'E1 EGT3', 'E1 EGT4']])
# Out:
#              E1 EGT1        E1 EGT2        E1 EGT3        E1 EGT4
# count  695236.000000  695236.000000  695236.000000  695236.000000
# mean     1383.694167    1397.847899    1377.793845    1399.392265
# std        65.474158      70.193260      65.402308      63.940719
# min       634.230000     466.500000     651.820000     647.720000
# 25%      1346.930000    1359.570000    1342.650000    1366.180000
# 50%      1383.870000    1403.790000    1378.590000    1401.460000
# 75%      1425.770000    1441.872500    1419.710000    1442.960000
# max      1569.560000    1615.640000    1572.880000    1580.720000

# %% [markdown]
# # True airspeed

# %%
cruise.analyze(data['TAS'])
# Out:
# count    695236.000000
# mean        138.620608
# std          17.696060
# min          56.000000
# 25%         136.000000
# 50%         144.000000
# 75%         149.000000
# max         193.000000
# Name: TAS, dtype: float64

# %% [markdown]
# # Oil pressure and temperature

# %%
cruise.analyze(data['E1 OilP'])
# Out:
# count    695236.000000
# mean         75.220825
# std           2.504643
# min          46.560000
# 25%          73.610000
# 50%          75.240000
# 75%          76.740000
# max          95.270000
# Name: E1 OilP, dtype: float64

# %%
cruise.analyze(data['E1 OilT'])
# Out:
# count    695236.000000
# mean        189.609746
# std           5.313987
# min         117.410000
# 25%         187.540000
# 50%         189.730000
# 75%         192.160000
# max         219.750000
# Name: E1 OilT, dtype: float64

# %% [markdown]
# # Electrical system

# %%
cruise.analyze(data[['volt1', 'volt2']])
# Out:
#                volt1          volt2
# count  695236.000000  695236.000000
# mean       27.793288      28.733105
# std         0.237852       0.067319
# min         2.000000      22.200000
# 25%        27.800000      28.700000
# 50%        27.800000      28.700000
# 75%        27.800000      28.800000
# max        27.900000      28.800000
