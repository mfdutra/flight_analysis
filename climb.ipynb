# %% [markdown]
# # Climb data
#
# Everything is better explained in takeoff.ipynb

# %%
import iocommon
import logging
import matplotlib.pyplot as plt
import pandas as pd
import climb

# %matplotlib inline
plt.rcParams['figure.figsize'] = [18, 12]

data = climb.find_climb_data(pd.read_feather('/Users/mfdutra/Documents/flights.feather'))

# %% [markdown]
# # CHT

# %%
climb.analyze(data[['E1 CHT1', 'E1 CHT2', 'E1 CHT3', 'E1 CHT4']])
# Out:
#              E1 CHT1        E1 CHT2        E1 CHT3        E1 CHT4
# count  253837.000000  253837.000000  253837.000000  253837.000000
# mean      344.760311     341.672981     362.910932     357.570909
# std        26.157843      25.894496      27.610373      25.337063
# min       202.030000     177.660000     199.890000     200.670000
# 25%       327.950000     325.170000     345.090000     341.780000
# 50%       349.090000     346.710000     367.440000     361.620000
# 75%       363.970000     361.050000     383.690000     375.980000
# max       424.660000     411.060000     435.670000     429.730000

# %% [markdown]
# # EGT

# %%
climb.analyze(data[['E1 EGT1', 'E1 EGT2', 'E1 EGT3', 'E1 EGT4']])
# Out:
#              E1 EGT1        E1 EGT2        E1 EGT3        E1 EGT4
# count  253837.000000  253837.000000  253837.000000  253837.000000
# mean     1297.184415    1315.143278    1286.508683    1311.957142
# std        51.097470      50.820136      54.735379      54.440734
# min       830.270000     709.630000     838.140000     850.700000
# 25%      1270.090000    1288.500000    1257.300000    1282.090000
# 50%      1290.860000    1310.710000    1279.180000    1305.160000
# 75%      1312.170000    1332.890000    1300.110000    1329.120000
# max      1615.160000    1632.810000    1603.340000    1603.230000

# %% [markdown]
# # Vertical speed

# %%
climb.analyze(data['VSpd'])
# Out:
# count    253837.000000
# mean        584.464710
# std         263.670354
# min         200.010000
# 25%         383.070000
# 50%         543.380000
# 75%         742.760000
# max        4838.760000
# Name: VSpd, dtype: float64

# %% [markdown]
# # Oil pressure and temperature

# %%
climb.analyze(data['E1 OilP'])
# Out:
# count    253837.000000
# mean         77.024569
# std           3.034579
# min          52.450000
# 25%          75.010000
# 50%          76.880000
# 75%          78.760000
# max          95.120000
# Name: E1 OilP, dtype: float64

# %%
climb.analyze(data['E1 OilT'])
# Out:
# count    253837.000000
# mean        190.213471
# std          12.350198
# min         118.040000
# 25%         186.620000
# 50%         191.820000
# 75%         196.760000
# max         219.120000
# Name: E1 OilT, dtype: float64
